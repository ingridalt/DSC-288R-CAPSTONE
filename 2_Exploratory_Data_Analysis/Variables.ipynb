# %%
##taking a look at variables by mapping encoded column names to label

import pandas as pd

p_file = "data_persons_ca_1yr/2023/psam_p06.csv"
all_headers_persons = pd.read_csv(p_file, nrows=0).columns.tolist()

print("Number of columns:", len(all_headers_persons))
print("First 20 columns:", all_headers_persons[:20])
print("Last 10 columns:", all_headers_persons[-10:])
# Out:
# Number of columns: 287
# First 20 columns: ['RT', 'SERIALNO', 'DIVISION', 'SPORDER', 'PUMA', 'REGION', 'STATE', 'ADJINC', 'PWGTP', 'AGEP', 'CIT', 'CITWP', 'COW', 'DDRS', 'DEAR', 'DEYE', 'DOUT', 'DPHY', 'DRAT', 'DRATX']
# Last 10 columns: ['PWGTP71', 'PWGTP72', 'PWGTP73', 'PWGTP74', 'PWGTP75', 'PWGTP76', 'PWGTP77', 'PWGTP78', 'PWGTP79', 'PWGTP80']

# %%
import pandas as pd
import requests
import json

# 1) get column names
p_file = "data_persons_ca_1yr/2023/psam_p06.csv"
cols = pd.read_csv(p_file, nrows=0).columns.tolist()

print("Columns in file:", len(cols))
print("Example columns:", cols[:12])

# 2) fetch Census metadata dictionary
url = "https://api.census.gov/data/2023/acs/acs5/pums/variables.json"
meta = requests.get(url)
meta.raise_for_status()
vardict = meta.json()["variables"]

# 3) map each column -> explanation
rows = []
for c in cols:
    info = vardict.get(c, {})
    values_obj = info.get("values")
    rows.append({
        "column": c,
        "label": info.get("label"),
        "predicateType": info.get("predicateType"),
        "values_json": json.dumps(values_obj) if values_obj is not None else None
    })

df_dict = pd.DataFrame(rows)

# 5) save
df_dict.to_csv("Variable_exploration_data/all_pums_person_2023_data_dictionary.csv", index=False)
df_dict.head(20)
# Out:
# Columns in file: 287
# Example columns: ['RT', 'SERIALNO', 'DIVISION', 'SPORDER', 'PUMA', 'REGION', 'STATE', 'ADJINC', 'PWGTP', 'AGEP', 'CIT', 'CITWP']
#       column                                              label predicateType  \
# 0         RT                                        Record Type        string
# 1   SERIALNO               Housing unit/GQ person serial number        string
# 2   DIVISION                                      Division code          None
# 3    SPORDER                                      Person number           int
# 4       PUMA  Public use microdata area code (PUMA) based on...        string
# 5     REGION                                        Region code          None
# 6      STATE                                         State code          None
# 7     ADJINC  Adjustment factor for income and earnings doll...           int
# 8      PWGTP                                      Person weight           int
# 9       AGEP                                                Age           int
# 10       CIT                                 Citizenship status           int
# 11     CITWP                    Year of naturalization write-in           int
# 12       COW                                    Class of worker           int
# 13      DDRS                               Self-care difficulty           int
# 14      DEAR                                 Hearing difficulty           int
# 15      DEYE                                  Vision difficulty           int
# 16      DOUT                      Independent living difficulty           int
# 17      DPHY                              Ambulatory difficulty           int
# 18      DRAT  Veteran service connected disability rating (p...           int
# 19     DRATX  Veteran service connected disability rating (c...           int
#
#                                           values_json
# 0   {"item": {"H": "Housing Record or Group Quarte...
# 1                                                None
# 2   {"item": {"7": "West South Central (South Regi...
# 3   {"range": [{"min": "1", "max": "20", "descript...
# 4   {"item": {"00605": "Public use microdata area ...
# 5   {"item": {"1": "Northeast", "9": "Puerto Rico"...
# 6   {"item": {"47": "Tennessee/TN", "04": "Arizona...
# 7   {"item": {"1019518": "2023 factor (1.019518 * ...
# 8   {"range": [{"min": "1", "max": "9999", "descri...
# 9   {"item": {"0": "Under 1 year"}, "range": [{"mi...
# 10  {"item": {"2": "Born in Puerto Rico, Guam, the...
# 11  {"item": {"2023": "2023", "1960": "1960", "196...
# 12  {"item": {"9": "Unemployed and last worked 5 y...
# 13  {"item": {"1": "Yes", "0": "N/A (less than 5 y...
# 14                  {"item": {"2": "No", "1": "Yes"}}
# 15                  {"item": {"1": "Yes", "2": "No"}}
# 16  {"item": {"2": "No", "0": "N/A (Less than 15 y...
# 17  {"item": {"1": "Yes", "2": "No", "0": "N/A (le...
# 18  {"item": {"6": "Not reported", "4": "50 or 60 ...
# 19  {"item": {"2": "No", "1": "Yes", "0": "N/A (Le...

# %%
## original labels 

import pandas as pd
import json

# load your existing dictionary
df_dict = pd.read_csv(
    "Variable_exploration_data/all_pums_person_2023_data_dictionary.csv"
)

print("Original dictionary shape:", df_dict.shape)
df_dict.head()
# Out:
# Original dictionary shape: (287, 4)
#      column                                              label predicateType  \
# 0        RT                                        Record Type        string
# 1  SERIALNO               Housing unit/GQ person serial number        string
# 2  DIVISION                                      Division code           NaN
# 3   SPORDER                                      Person number           int
# 4      PUMA  Public use microdata area code (PUMA) based on...        string
#
#                                          values_json
# 0  {"item": {"H": "Housing Record or Group Quarte...
# 1                                                NaN
# 2  {"item": {"7": "West South Central (South Regi...
# 3  {"range": [{"min": "1", "max": "20", "descript...
# 4  {"item": {"00605": "Public use microdata area ...

# %%
## dropping useless columns

def is_useless(col):
    if col.startswith("PWG"):      # person weights + replicates
        return True
    if col.startswith("F"):        # allocation flags
        return True
    if col in ["RT", "SERIALNO", "SPORDER"]:  # pure identifiers
        return True
    return False

df_clean = df_dict.loc[~df_dict["column"].apply(is_useless)].copy()

print("Clean dictionary shape:", df_clean.shape)
df_clean.head()
# Out:
# Clean dictionary shape: (123, 4)
#      column                                              label predicateType  \
# 2  DIVISION                                      Division code           NaN
# 4      PUMA  Public use microdata area code (PUMA) based on...        string
# 5    REGION                                        Region code           NaN
# 6     STATE                                         State code           NaN
# 7    ADJINC  Adjustment factor for income and earnings doll...           int
#
#                                          values_json
# 2  {"item": {"7": "West South Central (South Regi...
# 4  {"item": {"00605": "Public use microdata area ...
# 5  {"item": {"1": "Northeast", "9": "Puerto Rico"...
# 6  {"item": {"47": "Tennessee/TN", "04": "Arizona...
# 7  {"item": {"1019518": "2023 factor (1.019518 * ...

# %%
df_clean.to_csv(
    "Variable_exploration_data/suggested_clean_data_dictionary.csv",
    index=False
)

print("Saved: suggested_clean_data_dictionary.csv")
# Out:
# Saved: suggested_clean_data_dictionary.csv

# %%
## 123 variables is still too many, lets try to cut it down further
# lets try to remove: columns with too many null values, columns that ariables that measure the same concept at different resolutions 
import pandas as pd

df = pd.read_csv(
    "Variable_exploration_data/suggested_clean_data_dictionary.csv"
)

print("Starting columns:", df.shape[0])
# Out:
# Starting columns: 123

# %%
import pandas as pd

dict_path = "Variable_exploration_data/suggested_clean_data_dictionary.csv"
df_dict = pd.read_csv(dict_path)

candidate_cols = df_dict["column"].tolist()
print("Number of candidate columns:", len(candidate_cols))
# Out:
# Number of candidate columns: 123

# %%
p_file = "data_persons_ca_1yr/2023/psam_p06.csv"

df = pd.read_csv(
    p_file,
    usecols=candidate_cols
)

print("Shape of loaded data:", df.shape)
# Out:
# Shape of loaded data: (392318, 123)

# %%
null_summary = (
    df.isna()
      .sum()
      .reset_index()
      .rename(columns={"index": "column", 0: "n_null"})
)

null_summary["pct_null"] = null_summary["n_null"] / len(df)

null_summary = null_summary.sort_values("pct_null", ascending=False)

# load dictionary if not already loaded
df_dict = pd.read_csv(
    "Variable_exploration_data/suggested_clean_data_dictionary.csv"
)

# keep only what we need
labels = df_dict[["column", "label"]]

# merge labels into null summary
null_summary = null_summary.merge(
    labels,
    on="column",
    how="left"
)

# reorder columns for readability
null_summary = null_summary[
    ["column", "label", "n_null", "pct_null"]
]

# %%
null_summary.head(60)
# Out:
#        column                                              label  n_null  \
# 0         GCM       Length of time responsible for grandchildren  390290
# 1        DRAT  Veteran service connected disability rating (p...  387851
# 2         GCR         Grandparents responsible for grandchildren  381734
# 3        MLPA                     Served September 2001 or later  375293
# 4        MLPJ  Served World War II (December 1941 - December ...  375293
# 5       MLPIK                 Peacetime service before July 1950  375293
# 6       MLPFG                   Served February 1955 - July 1964  375293
# 7        MLPE      Served Vietnam era (August 1964 - April 1975)  375293
# 8        MLPH       Served Korean War (July 1950 - January 1955)  375293
# 9       MLPCD                        Served May 1975 - July 1990  375293
# 10       MLPB  Served August 1990 - August 2001 (including Pe...  375293
# 11        VPS                          Veteran period of service  375293
# 12        SFN                                   Subfamily number  374881
# 13        SFR                             Subfamily relationship  374881
# 14      DRATX  Veteran service connected disability rating (c...  372886
# 15      MIGSP   Migration recode - State or foreign country code  352168
# 16    MIGPUMA  Migration public use microdata area code (MIGP...  352168
# 17      CITWP                    Year of naturalization write-in  329629
# 18        ESP                       Employment status of parents  323212
# 19        NOP                                 Nativity of parent  323212
# 20       SCHG                              Grade level attending  301029
# 21     DECADE                                    Decade of entry  279878
# 22       YOEP                                      Year of entry  279878
# 23    SCIENGP  Field of degree science and engineering flag -...  275105
# 24  SCIENGRLP  Field of degree science and engineering relate...  275105
# 25    DRIVESP            Number of vehicles calculated from JWRI  254057
# 26      JWRIP                                  Vehicle occupancy  254057
# 27       JWAP          Time of arrival at work - hour and minute  238536
# 28       JWDP       Time of departure for work - hour and minute  238536
# 29      JWMNP                                Travel time to work  238536
# 30        ENG                           Ability to speak English  232581
# 31       LANP         Language other than English spoken at home  232581
# 32       PAOC                   Presence and age of own children  231907
# 33      POWSP    Place of work - State or foreign country recode  209917
# 34     JWTRNS                    Means of transportation to work  209917
# 35    POWPUMA  Place of work public use microdata area code (...  209917
# 36       WKWN  Weeks worked during past 12 months (2019 or la...  187936
# 37       WKHP         Usual hours worked per week past 12 months  187936
# 38      MARHD                     Divorced in the past 12 months  177463
# 39      MARHM                      Married in the past 12 months  177463
# 40      MARHT                            Number of times married  177463
# 41      MARHW                      Widowed in the past 12 months  177463
# 42     MARHYP                                  Year last married  177463
# 43       INDP  Industry recode for 2023 and later based on 20...  157102
# 44     NAICSP  North American Industry Classification System ...  157102
# 45        COW                                    Class of worker  157102
# 46       SOCP  Standard Occupational Classification (SOC) cod...  157102
# 47       OCCP  Occupation recode for 2018 and later based on ...  157102
# 48        GCL             Grandparents living with grandchildren  132432
# 49        WRK                                   Worked last week  111443
# 50        MIL                                   Military service   67852
# 51        ESR                           Employment status recode   62889
# 52        WKL                                   When last worked   62889
# 53       NWRE  Informed of recall (UNEDITED-See 'Employment S...   62889
# 54       NWLK  Looking for work (UNEDITED-See 'Employment Sta...   62889
# 55       NWAB  Temporary absence from work (UNEDITED-See 'Emp...   62889
# 56      PERNP  Total person's earnings (use ADJINC to adjust ...   62889
# 57       NWAV  Available for work (UNEDITED-See 'Employment S...   62889
# 58       NWLA  On layoff from work (UNEDITED-See 'Employment ...   62889
# 59       RETP  Retirement income past 12 months (use ADJINC t...   58042
#
#     pct_null
# 0   0.994831
# 1   0.988614
# 2   0.973022
# 3   0.956604
# 4   0.956604
# 5   0.956604
# 6   0.956604
# 7   0.956604
# 8   0.956604
# 9   0.956604
# 10  0.956604
# 11  0.956604
# 12  0.955554
# 13  0.955554
# 14  0.950469
# 15  0.897660
# 16  0.897660
# 17  0.840209
# 18  0.823852
# 19  0.823852
# 20  0.767309
# 21  0.713396
# 22  0.713396
# 23  0.701230
# 24  0.701230
# 25  0.647579
# 26  0.647579
# 27  0.608017
# 28  0.608017
# 29  0.608017
# 30  0.592838
# 31  0.592838
# 32  0.591120
# 33  0.535068
# 34  0.535068
# 35  0.535068
# 36  0.479040
# 37  0.479040
# 38  0.452345
# 39  0.452345
# 40  0.452345
# 41  0.452345
# 42  0.452345
# 43  0.400446
# 44  0.400446
# 45  0.400446
# 46  0.400446
# 47  0.400446
# 48  0.337563
# 49  0.284063
# 50  0.172952
# 51  0.160301
# 52  0.160301
# 53  0.160301
# 54  0.160301
# 55  0.160301
# 56  0.160301
# 57  0.160301
# 58  0.160301
# 59  0.147946

# %%
# lets drop any columns that have over 85% null values 

HIGH_NULL_CUTOFF = 0.85

# 1) Load your current clean dictionary (the 123-col list)
df_dict = pd.read_csv(dict_path)
candidate_cols = df_dict["column"].tolist()

# 2) Load ONLY those columns from the person CSV
df = pd.read_csv(p_file, usecols=candidate_cols)

# 3) Compute null rates
null_summary = (
    df.isna()
      .sum()
      .reset_index()
      .rename(columns={"index": "column", 0: "n_null"})
)
null_summary["pct_null"] = null_summary["n_null"] / len(df)

# 4) Identify high-null columns to drop
high_null_cols = null_summary.loc[
    null_summary["pct_null"] >= HIGH_NULL_CUTOFF,
    "column"
].tolist()

print(f"Columns in dict before: {len(candidate_cols)}")
print(f"Dropping (pct_null >= {HIGH_NULL_CUTOFF}): {len(high_null_cols)}")
print("Dropped columns:", high_null_cols)

# 5) Prune dictionary and overwrite the same file
df_dict_pruned = df_dict.loc[~df_dict["column"].isin(high_null_cols)].copy()
df_dict_pruned.to_csv(dict_path, index=False)

print(f"Columns in dict after: {df_dict_pruned.shape[0]}")
# Out:
# Columns in dict before: 123
# Dropping (pct_null >= 0.85): 17
# Dropped columns: ['DRAT', 'DRATX', 'GCM', 'GCR', 'MLPA', 'MLPB', 'MLPCD', 'MLPE', 'MLPFG', 'MLPH', 'MLPIK', 'MLPJ', 'MIGPUMA', 'MIGSP', 'SFN', 'SFR', 'VPS']
# Columns in dict after: 106

# %%
## 106 might still be too many... our best might be measuring feature importance or
## manually picking columns
